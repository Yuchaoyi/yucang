# %%
s=0
for i in range(1,101):
    if i%2!=0:
        s+=i
        print(f'第{(i+1)//2}个奇数为：',i,end='          ')
    if ((i+1)//2)%3==0:
        print()
print('奇数之和为：',s)
# Out:
# 第1个奇数为： 1          第2个奇数为： 3          第3个奇数为： 5
#
# 第4个奇数为： 7          第5个奇数为： 9          第6个奇数为： 11
#
# 第7个奇数为： 13          第8个奇数为： 15          第9个奇数为： 17
#
# 第10个奇数为： 19          第11个奇数为： 21          第12个奇数为： 23
#
# 第13个奇数为： 25          第14个奇数为： 27          第15个奇数为： 29
#
# 第16个奇数为： 31          第17个奇数为： 33          第18个奇数为： 35
#
# 第19个奇数为： 37          第20个奇数为： 39          第21个奇数为： 41
#
# 第22个奇数为： 43          第23个奇数为： 45          第24个奇数为： 47
#
# 第25个奇数为： 49          第26个奇数为： 51          第27个奇数为： 53
#
# 第28个奇数为： 55          第29个奇数为： 57          第30个奇数为： 59
#
# 第31个奇数为： 61          第32个奇数为： 63          第33个奇数为： 65
#
# 第34个奇数为： 67          第35个奇数为： 69          第36个奇数为： 71
#
# 第37个奇数为： 73          第38个奇数为： 75          第39个奇数为： 77
#
# 第40个奇数为： 79          第41个奇数为： 81          第42个奇数为： 83
#
# 第43个奇数为： 85          第44个奇数为： 87          第45个奇数为： 89
#
# 第46个奇数为： 91          第47个奇数为： 93          第48个奇数为： 95
#
# 第49个奇数为： 97          第50个奇数为： 99          奇数之和为： 2500
